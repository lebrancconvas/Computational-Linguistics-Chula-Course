# %%
# !pip install pythainlp
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 54.1 MB/s eta 0:00:00
# ...

# %%
import pythainlp

# %%
pythainlp.word_tokenize('คำอธิบายบนพรีเซนต์ผิดเยอะจนบอสเขม่น')
# Out:
# ['คำอธิบาย', 'บน', 'พรีเซนต์', 'ผิด', 'เยอะ', 'จน', 'บอส', 'เขม่น']

# %%
pythainlp.word_tokenize('อาจารย์สั่งโปรเจคที่ต้องคำนวนหาผลลัพธ์')
# Out:
# ['อาจารย์', 'สั่ง', 'โปรเจค', 'ที่', 'ต้อง', 'คำ', 'นว', 'น', 'หา', 'ผลลัพธ์']

# %%
'น' in pythainlp.tokenize.DEFAULT_DICT_TRIE.words
# Out:
# False

# %%
pythainlp.word_tokenize('กินยาโคเดอีนแล้วอาจช็อกได้')
# Out:
# ['กิน', 'ยา', 'โค', 'เด', 'อี', 'น', 'แล้ว', 'อาจ', 'ช็อก', 'ได้']
