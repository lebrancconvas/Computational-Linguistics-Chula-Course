# %%
# #Download pretrained TNC embeddings
# !gdown --id 14lAF3cOiYkcagFvNnW4o9BKIDXMB0RPg
# !gdown --id 14bv_aTSP-8rs_Bkudvpp8zcU3UpyRen6
# !gdown --id 14k1PLN9MVszCK6zUIRcLzWLwEGdR0ABw
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=14lAF3cOiYkcagFvNnW4o9BKIDXMB0RPg
# To: /content/TNC_embeddings-50.bin
# 100% 13.6M/13.6M [00:00<00:00, 30.9MB/s]
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=14bv_aTSP-8rs_Bkudvpp8zcU3UpyRen6
# To: /content/TNC_embeddings-100.bin
# 100% 25.9M/25.9M [00:00<00:00, 80.9MB/s]
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
# ...

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 33.5 MB/s eta 0:00:00
# ...

# %%
from gensim.models import KeyedVectors

# %%
tnc_embeddings =  KeyedVectors.load_word2vec_format("TNC_embeddings-50.bin", binary=True, unicode_errors='ignore')
# Out:
# WARNING:gensim.models.keyedvectors:duplicate word 'พระบาทสมเด็จพระพุทธยอดฟ้าจุฬาโลก' in word2vec file, ignoring all but first

# %%
tnc_embeddings.similar_by_word('เศรษฐกิจ')
# Out:
# [('ทุนนิยม', 0.7692354321479797),
#  ('เสถียรภาพ', 0.7293504476547241),
#  ('สังคม', 0.7219006419181824),
#  ('เศรษบกิจ', 0.6756314039230347),
#  ('พัฒนา', 0.6696383953094482),
#  ('เกษตร', 0.6626153588294983),
#  ('นโยบาย', 0.6591475605964661),
#  ('นิเวศ', 0.6562280058860779),
#  ('โลกาภิวัตน์', 0.6390718817710876),
#  ('วิกฤติการณ์', 0.6388400197029114)]

# %%
tnc_embeddings.get_vector('เศรษฐกิจ')
# Out:
# array([-0.08709697, -3.63716   , -1.2478586 ,  3.023878  ,  6.71986   ,
#        -3.5367854 , -1.8257816 , -1.4788129 ,  1.7396613 ,  3.323814  ,
#        -1.9533755 , -1.9349761 , -3.7950013 , -3.3189735 ,  1.8234869 ,
#        -2.5007133 ,  0.28863573, -2.2173111 ,  1.4836092 ,  1.7419088 ,
#         0.58905804, -4.364507  ,  1.2633331 , -0.96123683,  3.1058934 ,
#        -0.85789174,  0.2881306 ,  1.3667804 ,  1.7589158 , -0.73718154,
#         3.6375484 , -1.4470698 , -2.0833056 ,  0.8524132 ,  5.224239  ,
#        -1.7042111 ,  4.305014  ,  7.593572  ,  2.9003112 , -0.04765967,
#        -1.0210313 , -1.4679649 , -3.6454637 , -1.1101334 ,  1.210062  ,
#         3.7551634 , -0.4800399 ,  1.894872  , -1.6325045 , -1.9224002 ],
#       dtype=float32)

# %% [markdown]
# # GloVe Embeddings

# %%
# !wget https://nlp.stanford.edu/data/wordvecs/glove.2024.wikigiga.100d.zip
# Out:
# --2026-02-13 04:25:19--  https://nlp.stanford.edu/data/wordvecs/glove.2024.wikigiga.100d.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.cs.stanford.edu/nlp/data/wordvecs/glove.2024.wikigiga.100d.zip [following]
# --2026-02-13 04:25:20--  https://downloads.cs.stanford.edu/nlp/data/wordvecs/glove.2024.wikigiga.100d.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 581925049 (555M) [application/zip]
# Saving to: ‘glove.2024.wikigiga.100d.zip’
#
# glove.2024.wikigiga 100%[===================>] 554.97M  4.92MB/s    in 1m 48s
#
# ...

# %%
# !unzip glove.2024.wikigiga.100d.zip
# Out:
# Archive:  glove.2024.wikigiga.100d.zip
#   inflating: wiki_giga_2024_100_MFT20_vectors_seed_2024_alpha_0.75_eta_0.05.050_combined.txt

# %%
glove_path = '/content/wiki_giga_2024_100_MFT20_vectors_seed_2024_alpha_0.75_eta_0.05.050_combined.txt'
glove = KeyedVectors.load_word2vec_format(glove_path, binary=False, no_header=True, limit=20000)

# %%
glove.similar_by_word('liberty')
# Out:
# [('freedom', 0.7558746933937073),
#  ('pride', 0.630361795425415),
#  ('rights', 0.6290996074676514),
#  ('spirit', 0.6268742680549622),
#  ('dignity', 0.6041077971458435),
#  ('universal', 0.5958136916160583),
#  ('honor', 0.5957862734794617),
#  ('equality', 0.5954609513282776),
#  ('america', 0.5925919413566589),
#  ('true', 0.586134672164917)]
